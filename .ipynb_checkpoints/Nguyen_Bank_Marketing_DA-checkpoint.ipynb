# %%
# import libraries
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.plotting.register_matplotlib_converters()

# %% [markdown]
# ## I. Introduction
#
# https://www.kaggle.com/henriqueyamahata/bank-marketing

# %% [markdown]
# ### Input variables:
# * Bank client data:
#    1. age (numeric)
#    2. job : type of job (categorical: "admin.","blue-collar","entrepreneur","housemaid","management","retired","self-employed","services","student","technician","unemployed","unknown")
#    3. marital : marital status (categorical: "divorced","married","single","unknown"; note: "divorced" means divorced or widowed)
#    4. education (categorical: "basic.4y","basic.6y","basic.9y","high.school","illiterate","professional.course","university.degree","unknown")
#    5. default: has credit in default? (categorical: "no","yes","unknown")
#    6. housing: has housing loan? (categorical: "no","yes","unknown")
#    7. loan: has personal loan? (categorical: "no","yes","unknown")
# * Related with the last contact of the current campaign:
#    8. contact: contact communication type (categorical: "cellular","telephone")
#    9. month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#    10. day_of_week: last contact day of the week (categorical: "mon","tue","wed","thu","fri")
#    11. duration: last contact duration, in seconds (numeric). Important note:  this attribute highly affects the output target (e.g., if duration=0 then y="no"). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
# * Other attributes:
#    12. campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#    13. pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
#    14. previous: number of contacts performed before this campaign and for this client (numeric)
#    15. poutcome: outcome of the previous marketing campaign (categorical: "failure","nonexistent","success")
# * Social and economic context attributes
#    16. emp.var.rate: employment variation rate - quarterly indicator (numeric)
#    17. cons.price.idx: consumer price index - monthly indicator (numeric)
#    18. cons.conf.idx: consumer confidence index - monthly indicator (numeric)
#    19. euribor3m: euribor 3 month rate - daily indicator (numeric)
#    20. nr.employed: number of employees - quarterly indicator (numeric)
#
# ### Output variable (desired target):
#   21. y - has the client subscribed a term deposit? (binary: "yes","no")
#
# ### Missing Attribute Values:
# There are several missing values in some categorical attributes, all coded with the "unknown" label. These missing values can be treated as a possible class label or using deletion or imputation techniques.

# %% [markdown]
# ## 0. Introduction

# %% [markdown]
# ## I. Business Understanding

# %% [markdown]
# Euribor3m
# Mỗi ngày thị trường mở cửa, BBA khảo sát một nhóm các ngân hàng (18 ngân hàng lớn trên toàn cầu cho USD Libor), yêu cầu họ ước tính mức lãi suất mà họ sẽ phải trả để vay tiền từ các ngân hàng khác. Bốn phản hồi cao nhất và bốn thấp nhất bị loại bỏ và trung bình được tính dựa trên giữa 10. Trung bình này sau đó được báo cáo vào lúc 11:30 sáng theo tỷ lệ Libor cho ngày hôm đó.

# %% [markdown]
# ## II. DATA UNDERSTANDING

# %%
# get data banking marketing from file
file_path = "data/bank-additional-full.csv"
marketing_df = pd.read_csv(file_path,sep = ";")
marketing_df.head(5)
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
marketing_df.info()

# Thông tin tổng quan về bộ data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
categorical = marketing_df.dtypes[marketing_df.dtypes == 'object'].index.tolist()
numerical = marketing_df.dtypes[marketing_df.dtypes != 'object'].index.tolist()
print('numerical: '+str(len(numerical))+': '+str(numerical))
print('categorical: '+str(len(categorical))+': '+ str(categorical))

# Danh sách biến số và biến phân loại
# Out:
# numerical: 10: ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']
# categorical: 11: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'y']

# %%
len(marketing_df[marketing_df.duplicated(keep='first')])

# Số dòng trùng nhau
# Out:
# 12

# %%
#pdays = 999 --> trước đó chưa contacted
# define NA values:

na_lst = ["NA","","#NA","unknown"]
marketing_df = pd.read_csv(file_path, sep=';', na_values = na_lst, keep_default_na = True)

def missing_exploration(data):
    total = data.isnull().sum().sort_values(ascending=False)
    percent = round((data.isnull().sum()/data.isnull().count()*100),2).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent %'])
    return missing_data

missing_exploration(marketing_df)

# Tỉ lệ Missing của các biến
# Out:
#                 Total  Percent %
# default          8597      20.87
# education        1731       4.20
# housing           990       2.40
# loan              990       2.40
# job               330       0.80
# marital            80       0.19
# y                   0       0.00
# day_of_week         0       0.00
# contact             0       0.00
# month               0       0.00
# duration            0       0.00
# nr.employed         0       0.00
# campaign            0       0.00
# pdays               0       0.00
# previous            0       0.00
# poutcome            0       0.00
# emp.var.rate        0       0.00
# cons.price.idx      0       0.00
# cons.conf.idx       0       0.00
# euribor3m           0       0.00
# age                 0       0.00

# %%
#pdays = 999 --> trước đó chưa contacted
len(marketing_df[marketing_df['pdays'] == 999])/len(marketing_df) * 100

# Tỉ lệ missing của cột 'pdays'
# Out:
# 96.32174419733903

# %%
y_cnt = marketing_df.groupby('y').size().iloc[0]
y_name = marketing_df.groupby('y').size().index[0]
n_cnt = marketing_df.groupby('y').size().iloc[1]
n_name = marketing_df.groupby('y').size().index[1]
print("Tỉ lệ "+ str(y_name)+" label: " +str(y_cnt/(y_cnt+n_cnt)))
print("Tỉ lệ "+ str(n_name)+" label: " +str(n_cnt/(y_cnt+n_cnt)))

# Tỉ lệ các loại nhãn của biến targer
# Out:
# Tỉ lệ no label: 0.8873458288821987
# Tỉ lệ yes label: 0.11265417111780131

# %%
# marketing_df.groupby('y').size().sort_values(ascending=False).plot.pie(figsize=(15, 4),title = 'Target',autopct='%1.2f%%');
data = marketing_df.groupby('y').size().sort_values(ascending=False)
plt.pie(x=data , autopct="%.1f%%", explode=[0.05]*len(data), labels=data.index.tolist());
plt.title("The percentage of success");

# Visualization of the target

# %%
# đọc lại data:
marketing_df = pd.read_csv(file_path, sep=';')
marketing_df.shape
# Out:
# (41188, 21)

# %%
# xóa các dòng trùng nhau
marketing_df=marketing_df.drop(marketing_df[marketing_df.duplicated()].index).reset_index(drop=True)
marketing_df.shape
# Out:
# (41176, 21)

# %% [markdown]
# ### Summary
#
# Bộ Data được lấy từ một nghiên cứu vào năm 2014 của  UCI Machine Learning Repository dùng để dự đoán sự thành công của chiến dịch marketing bằng hình thức gọi điện của 1 ngân hàng ở Thổ Nhĩ Kỳ. Khảo sát tổng quan dữ liệu, ta nhận thấy:
# 1. Bộ dữ liệu có 41188 dòng và 21 cột, trong đó có 10 biến số và 11 biến phân loại. Ngoài ra, các biến này chứa các dữ liệu về khách hàng, thông tin về marketing và các chỉ số kinh tế và xã hội của khách hàng.
# 2. Bộ dữ liệu có 12 dòng trùng nhau, chiếm tỉ lệ rất nhỏ
#
# ### Target
# 1. Bộ dữ liệu có 88.7% nhãn 'no' và 11.3% nhãn 'yes', điều này chỉ ra rằng bộ dữ liệu nghiên cứu không cân bằng giữa tỉ lệ các kết quả thu được. Nó đồng thời cũng cho thấy rằng ngân hàng này đã thực hiện chiến dịch call marketing này một cách không tính toán nên tỉ lệ thành công thật sự thấp.
#
# ### Missing
# 1. Cột'default' có tỉ lệ missing là 20.87 xếp ở vị trí thứ 3
# 2. Các cột khác education, housing, loan, job, marital tỉ lệ missing không đáng kể
#
# ### Chú ý:
# 1. Cột 'pdays', giá trị missing '999' chiếm rất cao (96.32%)
# 2. Cột 'poutcome' có tỉ lện missing đứng thứ nhì (86.34)
#
# ### Thông tin chưa rõ
# 1. Các biến: emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m	được thu thập dữ liệu như thế nào

# %% [markdown]
# ## III. Data Exploration

# %% [markdown]
# ### Analysis: numerical

# %%
# Statistic các biến numerical:
marketing_df.describe()

# Khảo sát các thông số thống kê của các biến numerical
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
# Visualization các biến numerical:

numerical = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
             'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

for column in numerical:
    fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (12, 3));
    
    sns.histplot(marketing_df[column], ax=ax1, kde=True);
    ax1.set_xlabel(column);
    ax1.set_ylabel('Density');
    ax1.set_title(f'{column}  Distribution');

    sns.boxplot(x='y', y=column, data=marketing_df, showmeans=True, ax=ax2);
    ax2.set_xlabel('Target');
    ax2.set_ylabel(column);
    ax2.set_title(f'{column}  Distribution');

    plt.show();
    print();

# Distribution các biến numerical:

# %%
# Loại bỏ các giá trị '999' của pdays

data = marketing_df[marketing_df.pdays != 999]

column = 'pdays'
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (12, 3));

sns.histplot(data[column], ax=ax1, kde=True);
ax1.set_xlabel(column);
ax1.set_ylabel('Density');
ax1.set_title(f'{column}  Distribution');

sns.boxplot(x='y', y=column, data=data, showmeans=True, ax=ax2);
ax2.set_xlabel('Target');
ax2.set_ylabel(column);


# Distribution of  'pdays' khi loại bỏ các giá trị '999' của pdays

# %%
marketing_df[marketing_df['y'] == 'yes']['duration'].median()

# Thời lượng trunh bình của cuộc gọi gần nhất trong chiến dịch hiện tại ở những KH đồng ý gởi tiền
# Out:
# 449.0

# %% [markdown]
# (I). Numerical variables's Summary
#
# * Đa số khách hàng ở độ tuổi từ 30 - 50 tuổi. Những khách hàng đồng ý gởi tiền tập trung ở độ tuổi 30-50. Những người đồng ý gởi tiền mặc dù biên động rộng hơn những người từ chối, nhưng nhìn chung họ có độ tuổi trung bình trẻ hơn những người ko đồng ý
#
# * Thời gian của cuộc gọi gần nhất (duration) tập trung trong khoảng 0-200. Ta thấy những người có duration = 0 thì tỉ lệ thành công gần như là 0. Ở những trường hợp tiếp cận thành công, thời lượng trung bình của cuộc gọi gần nhất trong chiến dịch hiện tại khoảng 450 (tập trung trong khoảng < 1000)
#
# * Đến chiến dịch tiếp thị hiện tại, số cuộc gọi tập trung trong khoảng 1 - 3. Nhìn chung ở những người đồng ý gởi tiền, trung bình số contact thấp hơn ở những người ko đồng ý nên, tiếp cận nhiều chưa chắc mang lại hiệu quả cao.
#
# * Đa số chưa được tiếp xúc qua điện thoại ở chiến dịch quảng cáo trc đó (pdays = 999).
# Đối với những clients đã được tiếp cận ở chiến dịch trước (pdays != 999), đa số cuộc gọi cuối cùng của chiến dịch trước nằm trong khoảng 3 - 6 ngày (trong vòng 1 tuần). Trong đó, những trường hợp thành công có pdays trung bình là 5 ngày.
# > Không nên để mất liên lạc với khách hàng quá lâu. Chu kỳ tương tác tốt nhất giữa các chiến dịch sẽ là 5 ngày.
#
# * Phần nhiều, số cuộc gọi đến khách hàng thực hiện trước chiến dịch hiện tại (previous) phần nhiều nằm ở 0 --> Đa số khách hàng ở chiến dịch lần này là mới, chưa đc tiếp thị lần nào. Nhận thấy, trung bình số lần gọi đến khách hàng trước chiến dịch hiện tại ở những người đồng ý cao hơn ở nhóm người không đồng ý, lần lượt là 0.5 và 0. Có thể nói sự tương tác qua điện thoại đến khách hàng trước đó cũng ảnh hưởng đến kết quả của chiến dịch ở lần tiếp theo. (Nếu trước đó, khách hàng đã được chăm sóc, họ có xu hướng mua sản phẩm sẽ được tiếp thị)
#
# * Các biến social/economic variable chưa rõ cách thức thu thập
#
# * Đối với hệ số em.var.rate (hệ số thay đổi công việc): KH được tiếp thị có tỉ lệ thay đổi công việc nằm từ -2 đến 1.2. Đặc biệt, những KH đồng ý gởi tiền đều có tỉ lệ này <0 (hiếm khi thay đổi công việc) và tỉ lệ này thấp hơn tỉ lệ trung bình của những người ko đồng ý gởi. Những người ít thay đổi công việc có xu hướng gởi tiền ngân hàng nhiều hơn người hay thay đổi công việc
# * Euribo3m (là tỉ lệ tham chiếu được xây dựng từ lãi suất trung bình mà các ngân hàng Châu Âu cung cấp cho vay ngắn hạn không có tài sản bảo đảm trên thị trường liên ngân hàng): nằm trong khoảng từ 1-5. So sánh 2 nhóm đồng ý gởi và không gởi, ta thấy trung bình chỉ số này ở nhóm người đồng ý thấp hơn nhóm không đồng ý.Điều này có nghĩa khi chỉ số euribo3m càng thấp thì càng có nhiều người gởi hơn.
# * nremployed nằm trong khoảng 5010 - 5210. Tương tự như chỉ số ở trên, khi chỉ số này càng thấp thì client càng có xu hướng gởi hơn.
# * Hệ số cons.price.idx (hệ số giá tiêu dùng): của khách hàng được gọi nằm trong khoảng 93-94. Tỉ lệ trung bình của chỉ số này ở những người đồng ý gởi thấp hơn những người ko gởi. Điều này có nghĩa là khi chỉ số giá tiêu dùng cao (giá trị hàng hóa bán ra cao), khách hàng sẽ ít có xu hướng gởi tiền.
# > Đối với 4 biến trên, nhìn chung, tỉ lệ trung bình của các chỉ số này ở những người đồng ý gởi tiền đều thấp hơn những người ko đồng ý gởi
#
# * Ngược lại là hệ số cons.conf.ind (chỉ số lạc quan thị trường), tỉ lệ trung bình ở những khách hàng tiếp thị thành công lại cao hơn. Tỉ lệ này nằm trong khoảng từ -45 đến -37. Điều này có nghĩa Khi khách hàng tin tưởng vào sức khỏe của nền kinh tế thì người ta cũng có xu hướng gởi tiền vào ngân hàng nhiều hơn.
#
# Đa số khách hàng được gọi điện có:
# * Công việc chủ yếu là blue-collar (công nhân), admin, technician, đã có gia đình và chưa xác định được có nợ xấu hay không và đa số không có các khoản nợ cá nhân
# * khoảng 65% khách hàng được call qua cellular
# * Không có sự phân biệt rõ ràng giữa các giá trị day_of_week của cuộc gọi gần nhất, nhưng có sự khác nhau về month của nó. Có đến 1/3 số cuộc gọi gần nhất được thực hiện trong tháng 5
#
# Những chú ý:
# * Cột 'duration' sẽ không được quan tâm trong quá trình phân tích và xử lý
# * Có 12 dòng trùng nhau sẽ cắt bỏ
#
# Missing: 7 columns
# * các giá trị unknown của các cột khác: loan, housing, default, marital, job
#
#
# Outlier:
# * Pdays, Age, campain, previous, cons.conf.idx
# * poutcome có giá trị 'nonexistent' khá cao

# %% [markdown]
# ### Analysis: categorical

# %%
def get_col_target(rows, cols,data):
    
    cols_lst = data[cols].unique().tolist()
    rows_lst = data.groupby(rows)[rows].count().sort_values(ascending = False).index.tolist()

    group_df = data.groupby([rows,cols]).size()
    dic = {}
    for item in cols_lst:
        vals = []
        for i in rows_lst:
            try:
                vals.append(group_df.loc[(i, item)])
            except:
                vals.append(0)
            finally:
                continue
        dic[item] = vals

    df = pd.DataFrame(dic,index = rows_lst)
    return(df)

# %%
marketing_df.describe(include = 'object')

# Statistic các biến categorical:
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41176    41176              41176   41176   41176  41176     41176
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10419    24921              12164   32577   21571  33938     26135
#
#         month day_of_week     poutcome      y
# count   41176       41176        41176  41176
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13767        8618        35551  36537

# %%
categorical = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
target = 'y'
for column in categorical:

    fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20,4))    
    data1 = marketing_df.groupby(column).size()
    ax1.pie(x=data1 , autopct="%.2f%%", explode=[0.05]*len(data1), labels=data1.index.tolist(),pctdistance=0.5, radius=1.1)
    ax1.set_title(f'{column}  Distribution')

    data2 = get_col_target(column, target,marketing_df)   
    data2.plot(kind='bar',stacked = True, ax=ax2);
    plt.xticks(rotation=45);
    
# Visualization các biến categorical:

# %%
# categorical = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
# target = 'y'

# for col in categorical:
#     plt.figure(figsize = (10,4))
#     sns.histplot(data=marketing_df, x=col,hue=target,multiple='stack')
#     plt.xticks(rotation = 45)
#     plt.ylabel(col+' Distribution')

# %%
# Tỉ lệ thành công trên từng nhóm đối tượng
categorical = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
target = 'y'
for column in categorical:
    data = get_col_target(column, target,marketing_df)
    data['yes_rate'] = round(data['yes']*100/(data['yes'] + data['no']),2)
    yes_rate_df =  data['yes_rate'].sort_values(ascending = False)

    
    plt.figure(figsize = (8,5))
    sns.barplot(y = yes_rate_df.values, x = yes_rate_df.index)
    plt.xticks(rotation = 45)
    plt.ylabel('Successful rate by '+ column)

# %%
# Hay quá
# pd.crosstab(bank['job'], bank['y'], normalize='index').sort_values(by='yes',ascending=False )

# %% [markdown]
# (II). Categorical variables's Summary
#
# 1. *Job: Mặc dù đối tượng thực hiện trên khách hàng làm Admin là lớn nhất nhưng Tỉ lệ thành công cao lại rơi vào các nhóm đối tượng là 'retired' và 'student'
#
# 2. Marital: Tỉ lệ thành công cao nhất ở Unknown, sau đó là single
#
# 3. *'Education: tỉ lệ gởi ở những đối tượng illiterate và unknow tương đối cao hơn so với các nhóm còn lại
#
# 4. *Default: đối với những người đã có nợ xấu, tỉ lệ thành công là rất thấp(hâu như là 0). Trong khi đó, những người unknow và no chưa có credit thì có xu hướng gởi tiết kiệm nhiều hơn
#
# 5. Housing: Tỉ lệ thành công ở nhóm không có nợ mua nhà cao hơn so với có nợ mua nhà. Tuy nhiên sự chênh lệch này không nhiều và không vì thế mà những người đang mang khoản nợ mua nhà lại ko đồng ý gửi lãi ngân hàng.
#
# 6. Loan: Tương tự như housing, mặc dù trên 80% khách hàng được tiếp cận là không có các khoản nợ cá nhân, tuy nhiên tỉ lệ thành công so với nhóm đối tượng có nợ cá nhân và không có nợ cá nhân khá tương đương nhau.
#
#
# 7. *Contact: Hơn 60% khách hàng được tiếp cận thông qua cellphone và tỉ lệ thành công trên hình thức này cũng cao hơn hẳn so với telephone
#
# 8. *Month: Mặc dù chiếm đa số là các cuộc gọi gần nhất của chiến dịch hiện tại đc thực hiện vào tháng 5. Tuy nhiên tỉ lệ thành công lại cao hơn khi các cuộc gọi được gọi vào tháng 3, tháng 9, tháng 10 và tháng 12
#
# 9. Day_of_week: không có sư khác biệt rõ rệt về tỉ lệ thành công khi so sánh các cuộc gọi gần nhất của campain hiện tại trong các ngày làm việc khác nhau, tuy nhiên tỉ lệ thành công những con số cao nhất và cao nhì vẫn nhận thấy được ở những cuộc gọi được thực hiện vào thứ 5 và thứ 3
#
# 10. *Poutcome: Những người đã đồng ý mua sản phẩm ở chiến dịch trước lại có xu hướng đồng ý cho chiến dịch tiếp theo. Tỉ lệ thành công cũng cao hơn khi tiếp cận với những khách hàng đã được tiếp cận ở những chiến dịch trước đó so với những khách hàng mới.

# %% [markdown]
# ### Data correlation

# %% [markdown]
# I. Sự tương quan giữa các biến numerical

# %%
def show_correlation_matrix(df, vmin_val = -1, vmax_val = 1):
    f, ax = plt.subplots(figsize=(15, 10))
    #matrix = np.triu(df.corr())
    sns.heatmap(df.corr(),cmap = "YlGnBu", fmt='.1f', annot=True ,vmin= vmin_val, vmax = vmax_val)
    plt.show()

show_correlation_matrix(marketing_df,vmin_val = -1)

# Ma trận tương quan giữa các biến

# %% [markdown]
# 1. Ta thấy nhóm các chỉ số nr.employed, emp.var.rate, euribor3m là nhóm có tương quan tỉ lệ thuận
# > 3 biến này có yếu tố tương đồng rất cao nên ta có thể chọn 1 biến để quan sát (để giảm chiều dữ liệu)
#
# 2. previous: có tương quan tỉ lệ nghịch với nhóm biến ở mục 1, tuy nhiên những hệ số này không quá quan trọng trong phạm vi xem xét

# %% [markdown]
# II. Xem xét sự consistence giữa các yếu tố của khách hàng mới
#
# 1. Khách hàng mới là: chưa được contact lần nào trong chiến dịch trước (previous = 0)
# * previous = 0: chưa được contact lần nào trước đó --> sẽ có poutcome = 'nonexistent"
# * pdays = 999: chưa được tiếp cận trong chiến dịch trước có thể trước đó đã được liên lạc (previous có thể = 0 hoặc !=0)

# %%
is_no_previous = (marketing_df['previous'] == 0) # chưa call lần nào trc đó
is_no_pdays = (marketing_df['pdays'] == 999) # chưa call trong chiến dịch trước nào
is_non_exist_poutcome = (marketing_df['poutcome'] == 'nonexistent') # không có kết quả của chiến dịch trước

print('is_no_previous: '+str(len(marketing_df[is_no_previous])))
print('is_non_exist_poutcome: '+str(len(marketing_df[is_non_exist_poutcome])))
print('is_no_pdays: '+str(len(marketing_df[is_no_pdays])))

print('is_no_previous - is_non_exist_poutcome: '+str(len(marketing_df[is_no_previous & is_non_exist_poutcome])))
print('is_no_previous - is_no_pdays: '+str(len(marketing_df[is_no_previous & is_no_pdays])))
# Out:
# is_no_previous: 35563
# is_non_exist_poutcome: 35563
# is_no_pdays: 39673
# is_no_previous - is_non_exist_poutcome: 35563
# is_no_previous - is_no_pdays: 35563

# %%
is_previous = (marketing_df['previous'] != 0) # đã liên lạc trước đó

# Khách hàng đã liên lạc trước đó nhưng chưa được call trong chiến dịch nào trước đó
print('Số khách hàng đã liên lạc nhưng chưa được call trong chiến dịch nào trc đó: '\
          +str(len(marketing_df[is_no_pdays & is_previous])))
print('Poutcome: '+str(marketing_df[is_no_pdays & is_previous]['poutcome'].value_counts().index[0]) +\
             ' '+str(marketing_df[is_no_pdays & is_previous]['poutcome'].value_counts().values[0]))
# Out:
# Số khách hàng đã liên lạc nhưng chưa được call trong chiến dịch nào trc đó: 4110
# Poutcome: failure 4110

# %% [markdown]
# 2. Tỉ lệ chuyển đổi
# * N -> Y, Y->N, Y-Y, New -> N, N -> Y

# %%
def visualize_numerical(df, column, target = 'y'):

    fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (12, 3));

    sns.histplot(df[column], ax=ax1, kde=True);
    ax1.set_xlabel(column);
    ax1.set_ylabel('Density');
    ax1.set_title(f'{column}  Distribution');

    sns.boxplot(x=target, y=column, data=df, showmeans=True, ax=ax2);
    ax2.set_xlabel('Target');
    ax2.set_ylabel(column);
    plt.show()

def visualize_numerical_lst(df, numerical = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',\
                            'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'], target = 'y'):
    for column in numerical:
        visualize_numerical(df,column)
        print();
        
        
def visualize_categorical(df, column, target = 'y'):
    
        fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20,4))    
        data1 = df.groupby(column).size()
        ax1.pie(x=data1 , autopct="%.2f%%", explode=[0.05]*len(data1), labels=data1.index.tolist(),pctdistance=0.5, radius=1.1)
        ax1.set_title(f'{column}  Distribution')

        data2 = get_col_target(column, target,df)   
        data2.plot(kind='bar',stacked = True, ax=ax2);
        plt.xticks(rotation=45);
        
        plt.show()
    
    
def visualize_categorical_lst(df,categorical = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',\
                                          'month', 'day_of_week', 'poutcome'], target = 'y'):
    
    
    for column in categorical:
        visualize_categorical(df, column)
        
def visualize_success_rate(df,categorical = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',\
                                          'month', 'day_of_week', 'poutcome'], target = 'y'):
    
    for column in categorical:
        data = get_col_target(column, target,df)
        data['yes_rate'] = round(data['yes']*100/(data['yes'] + data['no']),2)
        yes_rate_df =  data['yes_rate'].sort_values(ascending = False)


        plt.figure(figsize = (8,5))
        sns.barplot(y = yes_rate_df.values, x = yes_rate_df.index)
        plt.xticks(rotation = 45)
        plt.ylabel('Successful rate by '+ column)

# %%
# Tỉ lệ chuyển đổi N -> Y
is_current_y = marketing_df['y'] == 'yes'
is_current_n = marketing_df['y'] == 'no'

is_previous_y = marketing_df['poutcome'] == 'success'
is_previous_n = marketing_df['poutcome'] == 'failure'

is_newcommer_y = (marketing_df['previous'] == 0) & (marketing_df['y'] == 'yes')
is_newcommer_n = (marketing_df['previous'] == 0) & (marketing_df['y'] == 'no')
is_newcommer = (marketing_df['previous'] == 0)

newcommer_df = marketing_df[is_newcommer]

failure_df = marketing_df[is_previous_n]
success_df = marketing_df[is_previous_y]

fail_cnt = len(failure_df)
success_cnt = len(success_df)
fail_to_yes_cnt = len(marketing_df[is_previous_n & is_current_y])
success_to_no_cnt = len(marketing_df[is_previous_y & is_current_n])

print('No Failure: '+ str(len(failure_df)))
print('No Success: '+ str(len(success_df)))
print('Rate of Failure to YES: '+ str(fail_to_yes_cnt*100/fail_cnt))
print('Rate of success to NO: '+ str(success_to_no_cnt*100/success_cnt))
print('Cnt of new clients: '+str(len(newcommer_df)) + ' '+str(len(newcommer_df)/len(marketing_df)*100)+"%")
# Out:
# No Failure: 4252
# No Success: 1373
# Rate of Failure to YES: 14.22859830667921
# Rate of success to NO: 34.8871085214858
# Cnt of new clients: 35563 86.3431096435855%

# %%
visualize_numerical_lst(failure_df);

# Visulize nhóm khách hàng từ failure

# %%
categorical = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',\
                                          'month', 'day_of_week', 'poutcome']
cols = [i for i in categorical if i != 'poutcome']
visualize_success_rate(failure_df, categorical = cols)

# Visulize nhóm khách hàng từ failure

# %%
visualize_numerical_lst(success_df);
# Visualize từ khách hàng success từ chiến dịch trước

# %% [markdown]
# SUMMARY:
#
# 1. Xem xét khách hàng mới:
#     * Những clients có previous = 0 thì có poutcome = 'nonexistent và pdays = '999' --> ta sẽ xếp vào 1 nhóm gọi là khách hàng mới?
#     * Những clients có previous!= 0 và pdays = '999' ==> poutcome = 'failure' --> Không tiếp cận trong chiến dịch trc đó thì poutcome sẽ cho là failure
#
#
# 2. Tỉ lệ chuyển đổi: Tỉ lệ chuyển đổi từ Failure to YES là 14% trong khi tỉ lệ chuyển đổi từ Success to NO gần 35%. Ở đây có sự mất khách hàng.
#
# * của Failure Clients (thất bại ở chiến dịch lần trước):
#     - duration: Đối với chiến dịch lần này, so với những khách hàng say NO, những người say YES có thời lượng cuộc gọi gần nhất trong chiến dịch lần này dài hơn --> tư vấn càng kĩ thì tỉ lệ chuyển sang thành công càng lớn
#     - Tỉ lệ thành công trên những khách hàng độc thân (single) cao nhất
#     - Đối với campain hiện tại, cuộc gọi gần nhất được thực hiện vào tháng 7, tháng 3  sẽ cho tỉ lệ cao, tương tự, nếu gọi vào ngày thứ 3, thứ 4 cũng cho tỉ lệ cao
#     - chỉ số cons.conf.idx: Ở những khách hàng chuyển sang say YES ở chiến dịch hiện tại, 2 chỉ số cons.conf.idx và cons.price.idx có giá trị trung bình cao hơn so với những người say NO. Điều này có nghĩa là khi người ta cảm thấy lạc quan về nền kinh tế hoặc khi cuộc sống trở nên đắt đỏ hơn thì những người trc đó ko gởi tiền lại có xu hướng gởi
#     - Đối với 2 chỉ số emp.var.rate, euribo3m và nr.emplyed xu hướng ngược lại được tìm thấy, nhóm say YES có chỉ số trung bình thấp hơn nhóm say NO.
#
# * của Success Clients (Thành công ở lần trước ở chiến dịch lần trước): Có thể thấy có sự khác nhau về 5 chỉ số về kinh tế và xã hội đã làm cho các khách hàng thành công ở campain trước đó đưa ra những quyết định khác nhau về chiến dịch lần này:
#     - Ở những khách hàng tiếp tục say YES ở chiến dịch hiện tại, 2 chỉ số cons.conf.idx và cons.price.idx có giá trị trung bình cao hơn so với những người say NO
#     - Đối với 2 chỉ số euribo3m và nr.emplyed xu hướng ngược lại được tìm thấy, hóm say YES có chỉ số trung bình thấp hơn nhóm say NO
#     - trong khi chỉ số emp.var.rate thì hoàn toàn giống nhau
# > Như vậy ta nhận thấy, trong cả 2 trường hợp, khi hệ số cons.conf.idx và cons.conf.ind tăng thì các khách hàng ở chiến dịch lần trc (mặc cho failure hay success) đều có xu hướng đồng ý gởi tiền ngân hàng trong chiến dịch tiếp theo.

# %% [markdown]
# ### Những chú ý cho quá trình xử lý
#
# 1. Lược bỏ dữ liệu
# * Cột 'duration' sẽ không được quan tâm trong quá trình phân tích và xử lý
# * Có 12 dòng trùng nhau sẽ cắt bỏ
#
# 2. Missing:
# * Pdays: giá trị '999'
#
# * các giá trị unknown của các cột khác: loan, housing, default, marital, job
#
#
# 3. Outlier:
# * Age, campain, previous, cons.conf.idx
#
# 4. Phân loại lại biến pdays
#
# 5. Clustering theo 3 chỉ số pdays,previous,poutcome
#
# 6. Sự tương quan giữa các biến:
# * 3 biến nr.employed, emp.var.rate, euribo3m là 3 biến có tương quan rất mạnh --> có thể lọc bớt để giảm chiều dữ liệu
